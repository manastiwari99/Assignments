# %% [markdown]
# **Question 1 :** Create a minimal router with two pages: Home (/) and About (/about).
# Show the links to move between pages.
#
# **Answer:**
#              **Project Structure:**
#
#
# ```
# /src
#   |-- App.js
#   |-- index.js
#   |-- Home.js
#   |-- About.js
# ```
#
#
# **index.js**

# %%
import React from 'react';
import ReactDOM from 'react-dom/client';
import { BrowserRouter } from 'react-router-dom';
import App from './App';

const root = ReactDOM.createRoot(document.getElementById('root'));
root.render(
  <BrowserRouter>
    <App />
  </BrowserRouter>
);

# %% [markdown]
# **App.js**

# %%
import React from 'react';
import { Routes, Route, Link } from 'react-router-dom';
import Home from './Home';
import About from './About';

function App() {
  return (
    <div>
      <nav>
        <Link to="/">Home</Link> |{' '}
        <Link to="/about">About</Link>
      </nav>

      <Routes>
        <Route path="/" element={<Home />} />
        <Route path="/about" element={<About />} />
      </Routes>
    </div>
  );
}

export default App;

# %% [markdown]
# **Home.js**

# %%
import React from 'react';

function Home() {
  return <h1>Welcome to the Home Page</h1>;
}

export default Home;

# %% [markdown]
# **About.js**

# %%
import React from 'react';

function About() {
  return <h1>About Us</h1>;
}

export default About;

# %% [markdown]
# **Question 2 :** After a user clicks “Save”, programmatically go to /thank-you
#
# **Answer:**  Updated App.js (with route for ThankYou page)

# %%
import React from 'react';
import { Routes, Route, Link } from 'react-router-dom';
import Home from './Home';
import About from './About';
import ThankYou from './ThankYou'; // new page

function App() {
  return (
    <div>
      <nav>
        <Link to="/">Home</Link> |{' '}
        <Link to="/about">About</Link>
      </nav>

      <Routes>
        <Route path="/" element={<Home />} />
        <Route path="/about" element={<About />} />
        <Route path="/thank-you" element={<ThankYou />} />
      </Routes>
    </div>
  );
}

export default App;

# %% [markdown]
# Home.js (with Save button and navigation)

# %%
import React from 'react';
import { useNavigate } from 'react-router-dom';

function Home() {
  const navigate = useNavigate();

  const handleSave = () => {
    // simulate save logic...
    console.log('Data saved!');

    // navigate to /thank-you
    navigate('/thank-you');
  };

  return (
    <div>
      <h1>Welcome to the Home Page</h1>
      <button onClick={handleSave}>Save</button>
    </div>
  );
}

export default Home;

# %% [markdown]
# **ThankYou.js**

# %%
import React from 'react';

function ThankYou() {
  return <h1>Thank you for saving!</h1>;
}

export default ThankYou;

# %% [markdown]
# **Question 3 :** Build a DashboardLayout that shows a heading and a menu. Inside it,
# render DashboardHome at /dashboard and Settings at /dashboard/settings.
#
# **Answer:**
#
# We'll create:
#
# 1. DashboardLayout.js – with a heading + menu (links)
#
# 2. DashboardHome.js – main dashboard page
#
# 3. Settings.js – settings page
#
# 4. Update routing in App.js to use nested routes
#
#
# **Project Structure**
#
#
#
# ```
# /src
#   |-- App.js
#   |-- DashboardLayout.js
#   |-- DashboardHome.js
#   |-- Settings.js
# ```
#
# **App.js**

# %%
import React from 'react';
import { Routes, Route, Link } from 'react-router-dom';
import DashboardLayout from './DashboardLayout';
import DashboardHome from './DashboardHome';
import Settings from './Settings';

function App() {
  return (
    <div>
      <nav>
        <Link to="/dashboard">Dashboard</Link>
      </nav>

      <Routes>
        <Route path="/dashboard" element={<DashboardLayout />}>
          <Route index element={<DashboardHome />} />
          <Route path="settings" element={<Settings />} />
        </Route>
      </Routes>
    </div>
  );
}

export default App;

# %% [markdown]
# **DashboardLayout.js**

# %%
import React from 'react';
import { Link, Outlet } from 'react-router-dom';

function DashboardLayout() {
  return (
    <div>
      <h1>Dashboard</h1>
      <nav>
        <Link to="/dashboard">Home</Link> |{' '}
        <Link to="/dashboard/settings">Settings</Link>
      </nav>
      <hr />
      <Outlet /> {/* This renders the nested route component */}
    </div>
  );
}

export default DashboardLayout;

# %% [markdown]
# **DashboardHome.js**

# %%
import React from 'react';

function DashboardHome() {
  return <h2>Welcome to your Dashboard</h2>;
}

export default DashboardHome;

# %% [markdown]
# **Settings.js**

# %%
import React from 'react';

function Settings() {
  return <h2>Dashboard Settings</h2>;
}

export default Settings;

# %% [markdown]
# **Question 4 :** Create a route /users/:userId. In the UserPage component, read the
# userId from the URL and display it.
#
# **Answer:** ** 1. Update App.js**

# %%
import React from 'react';
import { Routes, Route, Link } from 'react-router-dom';
import UserPage from './UserPage';

function App() {
  return (
    <div>
      <nav>
        <Link to="/users/1">User 1</Link> |{' '}
        <Link to="/users/42">User 42</Link>
      </nav>

      <Routes>
        <Route path="/users/:userId" element={<UserPage />} />
      </Routes>
    </div>
  );
}

export default App;

# %% [markdown]
# **2. UserPage.js**

# %%
import React from 'react';
import { useParams } from 'react-router-dom';

function UserPage() {
  const { userId } = useParams();

  return (
    <div>
      <h1>User Page</h1>
      <p>User ID: {userId}</p>
    </div>
  );
}

export default UserPage;

# %% [markdown]
# **Question 5 :** Only logged-in users should see /dashboard. Others should be redirected
# to /login. Write a minimal ProtectedRoute wrapper.
#
# **Answer:**  **1. Create a ProtectedRoute Component**

# %%
// ProtectedRoute.js
import React from 'react';
import { Navigate } from 'react-router-dom';

function ProtectedRoute({ isLoggedIn, children }) {
  if (!isLoggedIn) {
    return <Navigate to="/login" replace />;
  }

  return children;
}

export default ProtectedRoute;

# %% [markdown]
# **2. Use ProtectedRoute in App.js**

# %%
import React from 'react';
import { Routes, Route } from 'react-router-dom';
import Dashboard from './Dashboard';
import Login from './Login';
import ProtectedRoute from './ProtectedRoute';

// Simulate login status
const isLoggedIn = false; // change to true to allow access

function App() {
  return (
    <Routes>
      <Route
        path="/dashboard"
        element={
          <ProtectedRoute isLoggedIn={isLoggedIn}>
            <Dashboard />
          </ProtectedRoute>
        }
      />
      <Route path="/login" element={<Login />} />
    </Routes>
  );
}

export default App;

# %% [markdown]
# **3. Create Dashboard.js**

# %%
import React from 'react';

function Dashboard() {
  return <h1>Welcome to the Dashboard</h1>;
}

export default Dashboard;

# %% [markdown]
# **4. Create Login.js**

# %%
import React from 'react';

function Login() {
  return <h1>Please log in to continue</h1>;
}

export default Login;

# %% [markdown]
# **Question 6 :** Create a counter slice with increment and decrement. Configure the store
# and provide it to React.
#
# **Answer:**      **Project Structure**
#
#
# ```
# /src
#   |-- App.js
#   |-- Counter.js
#   |-- store.js
#   |-- features/
#         |-- counterSlice.js
#
# ```
# **1. counterSlice.js (Redux Slice)**

# %%
// src/features/counterSlice.js
import { createSlice } from '@reduxjs/toolkit';

const counterSlice = createSlice({
  name: 'counter',
  initialState: {
    value: 0
  },
  reducers: {
    increment: (state) => {
      state.value += 1;
    },
    decrement: (state) => {
      state.value -= 1;
    }
  }
});

export const { increment, decrement } = counterSlice.actions;
export default counterSlice.reducer;

# %% [markdown]
# **2. store.js (Redux Store Configuration)**

# %%
// src/store.js
import { configureStore } from '@reduxjs/toolkit';
import counterReducer from './features/counterSlice';

const store = configureStore({
  reducer: {
    counter: counterReducer
  }
});

export default store;

# %% [markdown]
# **3. index.js (Provide Redux Store to React)**

# %%
// src/index.js
import React from 'react';
import ReactDOM from 'react-dom/client';
import { Provider } from 'react-redux';
import App from './App';
import store from './store';

const root = ReactDOM.createRoot(document.getElementById('root'));
root.render(
  <Provider store={store}>
    <App />
  </Provider>
);

# %% [markdown]
# **4. Counter.js (Using Redux in Component)**

# %%
// src/Counter.js
import React from 'react';
import { useSelector, useDispatch } from 'react-redux';
import { increment, decrement } from './features/counterSlice';

function Counter() {
  const count = useSelector((state) => state.counter.value);
  const dispatch = useDispatch();

  return (
    <div>
      <h2>Counter: {count}</h2>
      <button onClick={() => dispatch(increment())}>+ Increment</button>
      <button onClick={() => dispatch(decrement())}>- Decrement</button>
    </div>
  );
}

export default Counter;

# %% [markdown]
# **5. App.js (Render the Counter)**

# %%
// src/App.js
import React from 'react';
import Counter from './Counter';

function App() {
  return (
    <div>
      <h1>Redux Counter App</h1>
      <Counter />
    </div>
  );
}

export default App;

# %% [markdown]
# **Question 7 :** Build a Counter component that shows the value and buttons to increment
# and decrement using Redux hooks.
#
# **Answer:** How to build a Counter component that:
#
# * Uses Redux Toolkit state
#
# * Uses Redux hooks (useSelector, useDispatch)
#
# * Allows increment and decrement

# %%
// Counter.js
import React from 'react';
import { useSelector, useDispatch } from 'react-redux';
import { increment, decrement } from './features/counterSlice';

function Counter() {
  // Read value from Redux store
  const count = useSelector((state) => state.counter.value);

  // Get dispatch function
  const dispatch = useDispatch();

  return (
    <div>
      <h2>Counter: {count}</h2>
      <button onClick={() => dispatch(increment())}>+ Increment</button>
      <button onClick={() => dispatch(decrement())}>- Decrement</button>
    </div>
  );
}

export default Counter;

# %% [markdown]
# **Question 8 :** Create a fetchProducts thunk that loads from `/api/products.` Handle
# loading and error in the slice.
#
# **Answer:**  how to create a fetchProducts thunk using Redux Toolkit that:
#
# * Loads product data from /api/products
#
# * Tracks loading and error states
#
# * Stores the fetched products in the Redux store
#
#
#
# **File: features/productsSlice.js**

# %%
import { createSlice, createAsyncThunk } from '@reduxjs/toolkit';

// 1. Create async thunk
export const fetchProducts = createAsyncThunk(
  'products/fetchProducts',
  async (_, thunkAPI) => {
    try {
      const response = await fetch('/api/products');
      if (!response.ok) {
        throw new Error('Failed to fetch products');
      }
      return await response.json();
    } catch (error) {
      return thunkAPI.rejectWithValue(error.message);
    }
  }
);

// 2. Create slice
const productsSlice = createSlice({
  name: 'products',
  initialState: {
    items: [],
    loading: false,
    error: null
  },
  reducers: {},
  extraReducers: (builder) => {
    builder
      .addCase(fetchProducts.pending, (state) => {
        state.loading = true;
        state.error = null;
      })
      .addCase(fetchProducts.fulfilled, (state, action) => {
        state.loading = false;
        state.items = action.payload;
      })
      .addCase(fetchProducts.rejected, (state, action) => {
        state.loading = false;
        state.error = action.payload || 'Something went wrong';
      });
  }
});

export default productsSlice.reducer;

# %% [markdown]
# **Add to store.js**

# %%
// store.js
import { configureStore } from '@reduxjs/toolkit';
import productsReducer from './features/productsSlice';

const store = configureStore({
  reducer: {
    products: productsReducer
  }
});

export default store;

# %% [markdown]
# **Example Component: Products.js**

# %%
import React, { useEffect } from 'react';
import { useDispatch, useSelector } from 'react-redux';
import { fetchProducts } from './features/productsSlice';

function Products() {
  const dispatch = useDispatch();
  const { items, loading, error } = useSelector((state) => state.products);

  useEffect(() => {
    dispatch(fetchProducts());
  }, [dispatch]);

  if (loading) return <p>Loading products...</p>;
  if (error) return <p>Error: {error}</p>;

  return (
    <div>
      <h2>Products</h2>
      <ul>
        {items.map((product) => (
          <li key={product.id}>{product.name}</li>
        ))}
      </ul>
    </div>
  );
}

export default Products;

# %% [markdown]
# **Question 9 :** Style a “Buy” button using Tailwind. Use a blue background, white text,
# and change the background shade on hover and focus.
#
# **Answer:**  To style a "Buy" button using Tailwind CSS with the following requirements:
#
# * Blue background
#
# * White text
#
# * Darker blue on hover
#
# * Same effect on focus
#
#
# **Tailwind Button Code**

# %%
<button class="bg-blue-600 text-white px-4 py-2 rounded hover:bg-blue-700 focus:bg-blue-700 focus:outline-none">
  Buy
</button>

# %% [markdown]
# **Question 10 :** Create a responsive product list: on small screens one column; on
# medium and up, three columns. Add a hover transition. Also, show how to reuse a utility
# group with @apply.
#
# **Answer:**    To build a responsive product list with Tailwind CSS, you’ll:
#
# * Show 1 column on small screens
#
# * Show 3 columns on md and up
#
# * Add a hover transition
#
# * Use @apply to reuse utilities in a custom CSS class
#
#
# **1. Responsive Product Grid with Hover**

# %%
<div class="grid grid-cols-1 md:grid-cols-3 gap-4 p-4">
  <div class="product-card">Product 1</div>
  <div class="product-card">Product 2</div>
  <div class="product-card">Product 3</div>
  <div class="product-card">Product 4</div>
</div>

# %% [markdown]
# **2. Reusable Utility Group using @apply**

# %%
/* styles.css or inside a <style> tag with Tailwind included */
@tailwind base;
@tailwind components;
@tailwind utilities;

@layer components {
  .product-card {
    @apply bg-white p-4 rounded shadow hover:shadow-lg transition duration-300;
  }
}
